# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = data.load_data()
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat','Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
train_images = train_images/255.0
test_images = test_images/255.0
plt.imshow(train_images[14], cmap=plt.cm.binary)

# %%
model = keras.Sequential(
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation="relu"),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=["accuracy"])
model.fit(train_images, train_labels, epochs=8)

test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# Epoch 1/8
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.4972 - accuracy: 0.8248
# Epoch 2/8
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.3700 - accuracy: 0.8650
# Epoch 3/8
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3334 - accuracy: 0.8773
# Epoch 4/8
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3096 - accuracy: 0.8865
# Epoch 5/8
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2938 - accuracy: 0.8917
# Epoch 6/8
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2777 - accuracy: 0.8971
# Epoch 7/8
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2675 - accuracy: 0.9017
# Epoch 8/8
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.2560 - accuracy: 0.9044
# 313/313 [==============================] - 2s 4ms/step - loss: 0.3566 - accuracy: 0.8750

# %%
for item in range(5):
    pred = model.predict(test_images)
    plt.imshow(test_images[item], cmap=plt.cm.binary)
    plt.show()
    print(f"{class_names[np.argmax(pred[item])]} actual label: {class_names[test_labels[item]]}")
# Out:
# 313/313 [==============================] - 1s 3ms/step
# Ankle boot actual label: Ankle boot
# 313/313 [==============================] - 1s 2ms/step
# Pullover actual label: Pullover
# 313/313 [==============================] - 1s 3ms/step
# Trouser actual label: Trouser
# 313/313 [==============================] - 1s 3ms/step
# Trouser actual label: Trouser
# 313/313 [==============================] - 1s 2ms/step
# T-shirt/top actual label: Shirt
