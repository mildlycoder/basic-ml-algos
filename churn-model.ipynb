# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('bank-churn.csv')

# %% [markdown]
# checking data types of every column to feed into model

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %% [markdown]
# Removing customerId and surname as it is useless for the prediction

# %%
df1 = df.drop(columns=['CustomerId', 'Surname'])

# %%
df1.dtypes
# Out:
# RowNumber            int64
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
for column in df1:
    if df1[column].dtype == 'object':
        print(f'{column}: {df1[column].unique()}')
# Out:
# Geography: ['France' 'Spain' 'Germany']
# Gender: ['Female' 'Male']

# %%
df1['Gender'].replace({'Female':1,'Male':0},inplace=True)

# %%
df2 = pd.get_dummies(data=df1, columns=['Geography'])
df2
# Out:
#       RowNumber  CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             1          619       1   42       2       0.00              1
# 1             2          608       1   41       1   83807.86              1
# 2             3          502       1   42       8  159660.80              3
# 3             4          699       1   39       1       0.00              2
# 4             5          850       1   43       2  125510.82              1
# ...         ...          ...     ...  ...     ...        ...            ...
# 9995       9996          771       0   39       5       0.00              2
# 9996       9997          516       0   35      10   57369.61              1
# 9997       9998          709       1   36       7       0.00              1
# 9998       9999          772       0   42       3   75075.31              2
# 9999      10000          792       1   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited  Geography_France  \
# 0             1               1        101348.88       1                 1
# 1             0               1        112542.58       0                 0
# 2             1               0        113931.57       1                 1
# 3             0               0         93826.63       0                 1
# 4             1               1         79084.10       0                 0
# ...         ...             ...              ...     ...               ...
# 9995          1               0         96270.64       0                 1
# 9996          1               1        101699.77       0                 1
# 9997          0               1         42085.58       1                 1
# 9998          1               0         92888.52       1                 0
# 9999          1               0         38190.78       0                 1
#
#       Geography_Germany  Geography_Spain
# 0                     0                0
# 1                     0                1
# 2                     0                0
# 3                     0                0
# 4                     0                1
# ...                 ...              ...
# 9995                  0                0
# 9996                  0                0
# 9997                  0                0
# 9998                  1                0
# 9999                  0                0
#
# [10000 rows x 14 columns]

# %%
cols_to_scale = ['CreditScore','Age','Tenure', 'Balance', 'EstimatedSalary']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])
df2
# Out:
#       RowNumber  CreditScore  Gender       Age  Tenure   Balance  \
# 0             1        0.538       1  0.324324     0.2  0.000000
# 1             2        0.516       1  0.310811     0.1  0.334031
# 2             3        0.304       1  0.324324     0.8  0.636357
# 3             4        0.698       1  0.283784     0.1  0.000000
# 4             5        1.000       1  0.337838     0.2  0.500246
# ...         ...          ...     ...       ...     ...       ...
# 9995       9996        0.842       0  0.283784     0.5  0.000000
# 9996       9997        0.332       0  0.229730     1.0  0.228657
# 9997       9998        0.718       1  0.243243     0.7  0.000000
# 9998       9999        0.844       0  0.324324     0.3  0.299226
# 9999      10000        0.884       1  0.135135     0.4  0.518708
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0                 1          1               1         0.506735       1
# 1                 1          0               1         0.562709       0
# 2                 3          1               0         0.569654       1
# 3                 2          0               0         0.469120       0
# 4                 1          1               1         0.395400       0
# ...             ...        ...             ...              ...     ...
# 9995              2          1               0         0.481341       0
# 9996              1          1               1         0.508490       0
# 9997              1          0               1         0.210390       1
# 9998              2          1               0         0.464429       1
# 9999              1          1               0         0.190914       0
#
#       Geography_France  Geography_Germany  Geography_Spain
# 0                    1                  0                0
# 1                    0                  0                1
# 2                    1                  0                0
# 3                    1                  0                0
# 4                    0                  0                1
# ...                ...                ...              ...
# 9995                 1                  0                0
# 9996                 1                  0                0
# 9997                 1                  0                0
# 9998                 0                  1                0
# 9999                 1                  0                0
#
# [10000 rows x 14 columns]

# %%
df2.dtypes
# Out:
# RowNumber              int64
# CreditScore          float64
# Gender                 int64
# Age                  float64
# Tenure               float64
# Balance              float64
# NumOfProducts          int64
# HasCrCard              int64
# IsActiveMember         int64
# EstimatedSalary      float64
# Exited                 int64
# Geography_France       uint8
# Geography_Germany      uint8
# Geography_Spain        uint8
# dtype: object

# %%
for col in df2:
    if col == 'CreditScore':
        continue
    print(f'{col}: {df2[col].unique()}')
# Out:
# RowNumber: [    1     2     3 ...  9998  9999 10000]
# Gender: [1 0]
# Age: [0.32432432 0.31081081 0.28378378 0.33783784 0.35135135 0.43243243
#  0.14864865 0.12162162 0.17567568 0.08108108 0.21621622 0.09459459
#  0.22972973 0.36486486 0.54054054 0.18918919 0.27027027 0.37837838
#  0.24324324 0.2027027  0.2972973  0.44594595 0.58108108 0.41891892
#  0.25675676 0.01351351 0.64864865 0.51351351 0.10810811 0.04054054
#  0.5        0.77027027 0.05405405 0.16216216 0.13513514 0.63513514
#  0.40540541 0.45945946 0.52702703 0.74324324 0.39189189 0.48648649
#  0.72972973 0.02702703 0.66216216 0.82432432 0.59459459 0.47297297
#  0.83783784 0.55405405 0.67567568 0.06756757 0.56756757 0.7027027
#  0.60810811 0.62162162 0.         0.86486486 0.68918919 0.75675676
#  0.71621622 0.78378378 0.7972973  0.94594595 0.90540541 0.89189189
#  0.81081081 0.85135135 1.         0.87837838]
# Tenure: [0.2 0.1 0.8 0.7 0.4 0.6 0.3 1.  0.5 0.9 0. ]
# Balance: [0.         0.33403148 0.63635718 ... 0.22865702 0.29922631 0.51870777]
# NumOfProducts: [1 3 2 4]
# HasCrCard: [1 0]
# IsActiveMember: [1 0]
# EstimatedSalary: [0.50673489 0.56270874 0.56965435 ... 0.21039009 0.46442905 0.19091423]
# Exited: [1 0]
# Geography_France: [1 0]
# Geography_Germany: [0 1]
# Geography_Spain: [0 1]

# %% [markdown]
# Splitting data for training

# %%
X = df2.drop('Exited', axis=1)
y = df2['Exited']
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train.shape
# Out:
# (8000, 13)

# %% [markdown]
# Making ANN using Keras

# %%
len(X_train.columns)
# Out:
# 13

# %%
model = keras.Sequential([
    keras.layers.Dense(13, input_shape=(13,), activation='relu'),
    keras.layers.Dense(9, activation="relu"),
    keras.layers.Dense(2, activation='sigmoid')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=["accuracy"])
model.fit(X_train, y_train, epochs=40)
model.evaluate(X_test, y_test)
# Out:
# Epoch 1/40
# 250/250 [==============================] - 1s 839us/step - loss: 0.8600 - accuracy: 0.7076
# Epoch 2/40
# 250/250 [==============================] - 0s 828us/step - loss: 0.7502 - accuracy: 0.7466
# Epoch 3/40
# 250/250 [==============================] - 0s 825us/step - loss: 0.8099 - accuracy: 0.7527
# Epoch 4/40
# 250/250 [==============================] - 0s 836us/step - loss: 0.6574 - accuracy: 0.7613
# Epoch 5/40
# 250/250 [==============================] - 0s 822us/step - loss: 0.6688 - accuracy: 0.7511
# Epoch 6/40
# 250/250 [==============================] - 0s 850us/step - loss: 0.6730 - accuracy: 0.7592
# Epoch 7/40
# 250/250 [==============================] - 0s 877us/step - loss: 0.5818 - accuracy: 0.7710
# Epoch 8/40
# 250/250 [==============================] - 0s 876us/step - loss: 0.6446 - accuracy: 0.7567
# Epoch 9/40
# 250/250 [==============================] - 0s 1ms/step - loss: 0.7135 - accuracy: 0.7423
# Epoch 10/40
# 250/250 [==============================] - 0s 842us/step - loss: 0.6837 - accuracy: 0.7515
# Epoch 11/40
# 250/250 [==============================] - 0s 870us/step - loss: 0.5930 - accuracy: 0.7699
# Epoch 12/40
# 250/250 [==============================] - 0s 854us/step - loss: 0.5752 - accuracy: 0.7728
# Epoch 13/40
# 250/250 [==============================] - 0s 843us/step - loss: 0.5945 - accuracy: 0.7705
# Epoch 14/40
# 250/250 [==============================] - 0s 904us/step - loss: 0.6060 - accuracy: 0.7613
# Epoch 15/40
# 250/250 [==============================] - 0s 876us/step - loss: 0.5876 - accuracy: 0.7706
